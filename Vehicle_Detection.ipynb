# %% [markdown]
# <a href="https://colab.research.google.com/github/Beyza-BEKDEMIR/Vehicle-Detection/blob/main/Vehicle_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
#GPU ve opencv kullanabilmek için makefile dosyasında yapılması gereken değişiklikler.
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet

# %%
#Darknet Build
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2023-08-17 13:10:15--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  17.3MB/s    in 15s
#
# 2023-08-17 13:10:30 (16.1 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#Öncelikle collabdan driveımıza bağlanmak için bir doğrulama yapmamız gerekiyor.
#Aşağıdaki kodu çalıştırarak çıkan linkte collab notebook'unu hangi hesabımız ile açtıysak o hesaba girerek gelen link ile doğrulama yapmalıyız.

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# oluşturduğumuz dosyayı kontrol edelim.
# !!ls /content/gdrive/My\ Drive/vehicles
# Out:
# ['classes.names\t      data.zip\ttrain.py',
#  'dataset-vehicles.zip  obj.data\tyolov3_custom.cfg']

# %%
# Yüklemiş olduğumuz .zip dosyasını collaba kopyalayalım

# !cp /content/gdrive/My\ Drive/vehicles/dataset-vehicles.zip ../

# %%
# kopyaladığımız dosyayı zipten çıkaralım.
# !unzip ../dataset-vehicles.zip -d data/
# Out:
# Archive:  ../dataset-vehicles.zip
# replace data/dataset-vehicles/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/notes.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test/img1027.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test.cache? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/val.cache? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test/img1047.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/train.cache? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test/img1040.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test/img1037.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/dataset-vehicles/labels/test/img1028.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# ...

# %% [markdown]
# Config Dosyasını Ayarlama

# %%
# !!ls /content/gdrive/My\ Drive/vehicles/yolov3_custom.cfg
# Out:
# ["'/content/gdrive/My Drive/vehicles/yolov3_custom.cfg'"]

# %%
# !cp /content/gdrive/My\ Drive/vehicles/yolov3_custom.cfg ./cfg

# %%
#Oluşturduğumuz obj.names ve obj.data dosyalarını google collaba aktaralım
# !cp /content/gdrive/My\ Drive/vehicles/classes.names ./data
# !cp /content/gdrive/My\ Drive/vehicles/obj.data  ./data

# %%
#Train dosyamızı google collaba kopyalayalım
# !cp /content/gdrive/My\ Drive/vehicles/train.py ./

# %%
#Şimdi bu python dosyasını çalıştırarak train için gerekli olayları bizim için yapmasını bekleyebiliriz.
# !python train.py

# %%
#Ağırlıkları alalım
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2023-08-17 15:15:48--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  17.3MB/s    in 10s
#
# 2023-08-17 15:15:58 (15.5 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# Eğitim

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg  -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.9.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.4
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   5 ->  416 x 416 x  32 0.498 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
